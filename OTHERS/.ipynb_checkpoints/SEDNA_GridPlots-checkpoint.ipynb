# %% [markdown]
# # Plots SEDNA grid characteristics

# %%
! date
# Out:
# Thu Dec 10 16:53:58 CET 2020

# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib as mpl

def Arc_plot(zlon,zlat,ztab,zcontours,zlim): 

    m = Basemap(projection='npstere',boundinglat=65,lon_0=-20, resolution='l')
    
    zfontsize=10
    m.drawparallels(np.arange(-90.,91.,5.),labels=[False,False,False,False], size=zfontsize, linewidth=0.3, alph=0.5)
    m.drawmeridians(np.arange(-180.,181.,20.),labels=[True,False,False,True], size=zfontsize, latmax=90.,linewidth=0.3,alpha=0.7)
    m.fillcontinents(color='grey')

    norm = mpl.colors.Normalize(vmin=limits[0], vmax=limits[1])

    X,Y = m(zlon,zlat)
    m.contourf(X,Y,ztab,zcontours,cmap='Spectral_r')
    plt.colorbar()
    
    zcontours=np.arange(0.,1000.,100)
    C=m.contour(X,Y,ztab,levels=zcontours,colors='black',alpha=0.8)
    plt.clabel(C,C.levels,inline=True,fmt='%.0f',fontsize=15)

# %% [markdown]
# # SEDNA grid

# %%
DDIR="/data0/project/drakkar/CONFIGS/ARC60/BATHY"
ds_sedna_bat=xr.open_dataset(DDIR+'/'+'ARC60_Etopo1_Bathymetry_LargeReady_20200808_Clean.nc')

# %%
tmask=xr.where(ds_sedna_bat['Bathymetry'] > 0. , 1., 0.)

# %%
CDIR='/data0/project/drakkar/CONFIGS/ARC60/COORD'
ds_coord=xr.open_dataset(CDIR+'/CREG60_coordinates_final_20200304.nc')

# %%
ds_coord
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 8050, y: 8505)
# Dimensions without coordinates: x, y
# Data variables:
#     nav_lon  (y, x) float64 ...
#     nav_lat  (y, x) float64 ...
#     glamt    (y, x) float64 ...
#     glamu    (y, x) float64 ...
#     glamv    (y, x) float64 ...
#     glamf    (y, x) float64 ...
#     gphit    (y, x) float64 ...
#     gphiu    (y, x) float64 ...
#     gphiv    (y, x) float64 ...
#     gphif    (y, x) float64 ...
#     e1t      (y, x) float64 ...
#     e1u      (y, x) float64 ...
#     e1v      (y, x) float64 ...
#     e1f      (y, x) float64 ...
#     e2t      (y, x) float64 ...
#     e2u      (y, x) float64 ...
#     e2v      (y, x) float64 ...
#     e2f      (y, x) float64 ...

# %%
ds_sel=xr.Dataset()
ds_sel.coords['nav_lat']=np.float(ds_sedna_bat['nav_lat'])
ds_sel.coords['nav_lon']=np.float(ds_sedna_bat['nav_lon'])
ds_sel['e1t']=np.float(ds_coord['e1t'])

# %%
ds_sel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-aabb9f4865be> in <module>
# ----> 1 ds_sel
#
# NameError: name 'ds_sel' is not defined

# %% [markdown]
# >>> # POLAR PLOTS

# %%
vmin=400. ; vmax=1000. ; vint=50.
contours=np.arange(vmin,vmax+vint,vint)
limits=[vmin,vmax]

plt.figure(figsize=(20,15))
plt.subplot(111)
Arc_plot(np.array(ds_sedna_bat['nav_lon']),np.array(ds_sedna_bat['nav_lat']), (xr.where(tmask ==0., np.nan,ds_coord['e1t'])), contours, limits)
#plt.text(0.7,0.9,'SEDNA horizontal grid resolution',fontsize=15)


#plt.subplot(222)
#Arc_plot(np.array(ds_ori['LON2D']),np.array(ds_ori['LAT2D']), ds_ori['mixing_power_bot_log10_msk'], contours, limits)

#plt.subplot(223)
#Arc_plot(np.array(ds_sedna_bat['nav_lon']),np.array(ds_sedna_bat['nav_lat']), (xr.where(tmask ==0., np.nan,ds_sedna_cri['cri_log10'])), contours, limits)

#plt.subplot(224)
#Arc_plot(np.array(ds_ori['LON2D']),np.array(ds_ori['LAT2D']), ds_ori['mixing_power_cri_log10_msk'], contours, limits)

plt.savefig('./FIGURES/SEDNA_GridRes.pdf')
